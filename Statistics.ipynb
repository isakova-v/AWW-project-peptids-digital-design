# %%
import pandas as pd
import plotly

file_path = '/Users/isakova.vmphystech.edu/Desktop/bio_ml/AWW/POSEIDON.csv'
df = pd.read_csv(file_path, sep=',', encoding='unicode_escape', on_bad_lines='skip')

df.head()
# Out:
#        Peptide     Cell line        Cargo  PubmedID Uptake  \
# 0  Tat (49-57)  Jurkat cells  Fluorescein  11087855    650
# 1  Tat (49-56)  Jurkat cells  Fluorescein  11087855  31.25
# 2  Tat (49-55)  Jurkat cells  Fluorescein  11087855     10
# 3  Tat (50-57)  Jurkat cells  Fluorescein  11087855   22.5
# 4  Tat (51-57)  Jurkat cells  Fluorescein  11087855     20
#
#                          Units    Conc.    Time Temp.          Method  \
# 0  Mean Fluorescence intensity  12.5 uM  15 min  23ºC  Flow cytometry
# 1  Mean Fluorescence intensity  12.5 uM  10 min  23ºC  Flow cytometry
# 2  Mean Fluorescence intensity  12.5 uM  10 min  23ºC  Flow cytometry
# 3  Mean Fluorescence intensity  12.5 uM  10 min  23ºC  Flow cytometry
# 4  Mean Fluorescence intensity  12.5 uM  10 min  23ºC  Flow cytometry
#
#               Type   Sequence
# 0  Cellular uptake  RKKRRQRRR
# 1  Cellular uptake   RKKRRQRR
# 2  Cellular uptake    RKKRRQR
# 3  Cellular uptake   KKRRQRRR
# 4  Cellular uptake    KRRQRRR

# %%
a = df['Cell line'].unique()
print(a)
print(len(a))
# Out:
# ['Jurkat cells' 'Aortic endothelial cells' 'Cortical striatal cells'
#  'HaCaT cells' 'NIH-3T3 cells' 'DAMI cells' 'HeLa cells' 'CHO cells'
#  'Human bowes melanoma cells' 'RAW264.7 cells' 'MCF7 cells'
#  'U373 MG cells' 'HS-68' 'Cos-7 cells' 'A549 cells' 'DU-145' 'Hifko cells'
#  'K562 cells' 'ECV304 cells' 'CHO-K1 cells' 'MC57'
#  'Rat alveolar epithelial cell monolayers (RAECM)' 'SK-OV-3 cells' 'PPC-1'
#  'M21' 'Human tongue squamous cell carcinoma (SCC) CAL 27'
#  'S-180 sarcoma cells' nan 'ZR-75-1 human breast cancer' 'PC3 cells'
#  'Ovcar-3 cells' 'Caco-2 cells' 'LNCaP'
#  'Mouse macrophage-like cell line J774 A.1'
#  'Mouse macrophage-like cell line J774 A.3'
#  'Mouse macrophage-like cell line J774 A.5'
#  'Mouse macrophage-like cell line J774 A.6'
#  'Mouse macrophage-like cell line J774 A.10' 'MDA-MB-231 cells'
#  'Human bronchial epithelial (HBE) cells' 'HepG2 cells'
#  'Pluripotent mouse mesenchymal progenitor cell line (C3H10T1/2)'
# ...

# %%
df.shape[0]
# Out:
# 2095
